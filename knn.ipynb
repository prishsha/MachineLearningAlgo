# %%
data = [
    [1.2, 3.5, 7.2, 'P'],
    [3.5, 5.0, 6.9, 'P'],
    [6.1, 4.9, 3.1, 'N'],
    [7.9, 2.1, 1.5, 'N'],
    [5.1, 6.7, 2.4, 'P'],
    [8.9, 7.5, 2.8, 'P'],
    [9.0, 6.5, 3.7, 'P'],
    [10.0, 4.0, 5.0, 'P']
]
target = [3, 4, 5]
